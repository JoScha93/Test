# %% [markdown]
# # Projektskizze - Erforderlicher Prüfungsleistung
#
# ---
# ### <u>Abgabetermin:</u> 15.12.2023 11:59 h (mittags)
#
# ### <u>Wie Sie einreichen: </u>
#
# 1. Füllen Sie dieses Dokument aus und speichern Sie Ihr bearbeitetes Notebook als .ipynb-Datei.
# 2. Benennen Sie das bearbeitete Notizbuch entsprechend der unten angegebenen Namenskonvention um!
# 3. Das Jupyter-Notebook sollte an Ihre*n Übungsleiter*in gehen. Laden Sie dazu das Notebook auf MyStudy(!) in Ihrer Übung hoch. Nach Rücksprache mit Ihrer Übungsleitung ist ggf. auch ein Versand per E-Mail in Ordnung.
# 4. Bitte reichen Sie nur eine Projektskizze pro Gruppe ab. Bestimmen Sie eine Person pro Gruppe, die dafür verantwortlich ist. Diese Person sollte auch den zweiten Projektbericht und die Präsentation in den folgenden Wochen einreichen.
#
# Es ist **wichtig**, dass Sie die bearbeiteten Jupyter-Notebook-Dateien, die Sie hochladen wollen (Dateikennung ".ipynb"), gem. der folgenden Namenskonvention:
# > Übungsnummer__NameDerFürDieEinreichungVerantwortlichenPerson_Projektskizze.ipynb verantwortlich ist
# > z.B. 15_Max_Mustermann_Projektskizze.ipynb
#
# (Hinweis: Ihre Übungsnummer ist die Nummer, die an den Namen der Python-Übung in MyStudy angehängt ist).

# %% [markdown]
# # 1. Problemübersicht
# ---

# %% [markdown]
# Skizzieren Sie das gewählte Problem/ Projekt. Wenn Sie sich beispielsweise für das Thema psychische Gesundheit und ihre Auswirkungen auf die Wirtschaft entschieden haben sollten, können Sie einen kurzen Bericht über psychische Gesundheit und ihre Auswirkungen auf die Wirtschaftsleistung eines Landes oder Unternehmens schreiben.

# %% [markdown]
# ...

# %% [markdown]
# # 2. Projektziele
# ---

# %% [markdown]
# Schreiben Sie die genauen Ziele auf, die Sie mit Ihrem Projekt erreichen wollen. Zum Beispiel: "Das Projekt zielt darauf ab festzustellen, welchen Einfluss Art und Umfang von präventiven Unterstützungsmaßnahmen zur Verbesserung der psychischen Gesundheit von MitarbeiterInnen auf die wirtschaftliche Leistung von Einzelunternehmen haben."

# %% [markdown]
# ...

# %% [markdown]
# # 3. Skizzieren Sie die Relevanz des Problems
# ---

# %% [markdown]
# Warum sollte man über dieses Problem nachdenken? Warum ist es wichtig?

# %% [markdown]
# ...

# %% [markdown]
# # 4. Datensatz/Datensätze
#
# ---

# %% [markdown]
# Finden Sie mindestens einen Datensatz, der zur Lösung des Problems/ Beantwortung der Frage beitragen kann, und referenzieren Sie diesen hier. Geben Sie eine kurze Beschreibung des Datensatzes (einschließlich Quellenangabe) und beschreiben Sie die Variablen. Notieren Sie auch wichtige Metriken, z.B. die Anzahl der Beobachtungen, die Anzahl der fehlenden Werte und die Anzahl der Variablen von Interesse usw.
#
# Sollten Sie keinen Datensatz finden können, der spannende Einsichten zu Ihrem Thema enthalten könnte, denken Sie darüber nach, wie Sie mittels einer Umfrage selbst Daten erheben könnten.

# %% [markdown]
# ...

# %% [markdown]
# # 5. Hilfsgesuch
#
# ---

# %% [markdown]
# Seien Sie so spezifisch wie möglich: Wobei können Ihnen die Lehrenden helfen?

# %% [markdown]
# ...

# %% [markdown]
# # 6. Aufgabenverteilung
#
# ---

# %% [markdown]
# Skizzieren Sie kurz die Aufgabenverteilung unter den Teammitgliedern für dieses Projekt. Achten Sie darauf, dass alle Gruppenmitglieder in diesem Abschnitt aufgeführt sind. Nur so können die Punkte entsprechend an diese Personen verteilt werden.
#
# Jedes Gruppenmitglied legt zu diesem Zweck eine Zelle an. Notieren Sie dort jeweils den vollständigen Namen, welche Rolle Sie einnehmen, welchen Beitrag Sie geleistet haben und welchen Sie in den kommenden Wochen zum Projekt leisten werden.
#
# Wir erwarten von jedem Teammitglied, dass es einen wesentlichen Beitrag zum Erfolg des Projekts leistet. Wir behalten uns vor, die Beiträge unterschiedlich zu bewerten, wenn deutlich wird, dass einzelne nicht zum Erfolg der Gruppe beitragen.

# %% [markdown]
# Vollständiger Name des Gruppenmitglieds 1: _Rolle_, _bisheriger Beitrag_, _erwarteter Beitrag_

# %% [markdown]
# ...

# %% [markdown]
# ...

# %% [markdown]
# ...
